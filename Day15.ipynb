# %%
# SyntaxError (example - commented because it breaks execution)
# print 'hello'

print("Hello World")  # correct


# NameError
try:
    print(age)
except NameError as e:
    print("NameError:", e)


# IndexError
numbers = [1, 2, 3, 4, 5]

try:
    print(numbers[10])
except IndexError as e:
    print("IndexError:", e)

# %%
# ModuleNotFoundError
try:
    import maths
except ModuleNotFoundError as e:
    print("ModuleNotFoundError:", e)


# AttributeError
import math

try:
    print(math.PI)
except AttributeError as e:
    print("AttributeError:", e)


# KeyError
user = {'name': 'Shivam', 'age': 24}

try:
    print(user['country'])
except KeyError as e:
    print("KeyError:", e)


# TypeError
try:
    print(4 + "3")
except TypeError as e:
    print("TypeError:", e)


# ValueError
try:
    int("12a")
except ValueError as e:
    print("ValueError:", e)


# ZeroDivisionError
try:
    print(10 / 0)
except ZeroDivisionError as e:
    print("ZeroDivisionError:", e)
