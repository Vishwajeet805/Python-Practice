# %%
# Empty dictionary
dog = {}

# Add values
dog["name"] = "Buddy"
dog["color"] = "Brown"
dog["breed"] = "Labrador"
dog["legs"] = 4
dog["age"] = 3

print(dog)

# Student dictionary
student = {
    "first_name": "Shivam",
    "last_name": "Singh",
    "gender": "Male",
    "age": 24,
    "marital_status": "Single",
    "skills": ["Python", "SQL"],
    "country": "India",
    "city": "Jabalpur",
    "address": "MP"
}

print(student)
